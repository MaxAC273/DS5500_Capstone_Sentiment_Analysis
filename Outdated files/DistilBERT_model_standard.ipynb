# %%
'''
This file contains the code for creating and evaluating
the BERT model for sentiment analysis.
This file comes after the data_preprocessing file.
'''
# Out:
# '\nThis file contains the code for creating and evaluating\nthe BERT model for sentiment analysis.\nThis file comes after the data_preprocessing file.\n'

# %%
#pip install transformers torch

# %%
# import the cleaned data from data_preprocessing file
import pandas as pd
df = pd.read_pickle("dataframe.pkl")

# %%
#remove rows for trying out model

#rows_to_keep = df.shape[0] // 120

#df = df.sample(n=rows_to_keep)

# %%
# Load the tokenizer and model

#DistilBERT model
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
#model="finiteautomata/bertweet-base-sentiment-analysis"
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=3)


#BERT model
# from transformers import BertTokenizer, BertForSequenceClassification


#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import pipeline

# Initialize the pipeline for sentiment analysis
#nlp = pipeline("sentiment-analysis", model=model)
nlp = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
# Making predictions
df['sentiment'] = df['cleaned_text'].apply(lambda x: nlp(x)[0]['label'])

# %%
import pickle
df.to_pickle("dataframe_DistilBert.pkl")

# %%
import pandas as pd
df = pd.read_pickle("dataframe_DistilBert.pkl")

# %%
type(df['sentiment'][0])
df
# Out:
#                      Unnamed: 0         hashed_userid masked_username  \
# tweetcreatedts
# 2022-07-01 06:53:25           0  13028308852725196659       *****roy1
# 2022-07-01 06:53:32           1  45494576030177085457     ******eam_6
# 2022-07-01 06:53:35           2  23641094384211702614     ******erlin
# 2022-07-01 06:53:38           3  21587659761682762378    ******oshi23
# 2022-07-01 06:53:40           4  47915146590553055505    ******4Truth
# ...                         ...                   ...             ...
# 2022-08-20 02:55:19      415367  83242079331442835051  *******tresist
# 2022-08-20 02:55:52      415368  98949018742144878760       *****ll42
# 2022-08-20 02:56:52      415369  42256911176251501556  *******eDuster
# 2022-08-20 02:57:39      415370  95273352056344375133       *****kh59
# 2022-08-20 02:57:54      415371  19868647935216335990       *****ecot
#
#                             location  following  followers  totaltweets  \
# tweetcreatedts
# 2022-07-01 06:53:25              NaN       9590       8725        29317
# 2022-07-01 06:53:32              NaN       8874      10090        33053
# 2022-07-01 06:53:35  Los Angeles, CA       7730      10006        35360
# 2022-07-01 06:53:38           Mumbai        232        132         4970
# 2022-07-01 06:53:40              NaN       6914       6310        49958
# ...                              ...        ...        ...          ...
# 2022-08-20 02:55:19              NaN        257        758       272531
# 2022-08-20 02:55:52              NaN        603        179        59766
# 2022-08-20 02:56:52         Chi-town        416       8852        11699
# 2022-08-20 02:57:39  Terre Haute, IN        854        298        16999
# 2022-08-20 02:57:54              NaN       1109        796       189199
#
#                     usercreateddt              tweetid  retweetcount  ...  \
# tweetcreatedts                                                        ...
# 2022-07-01 06:53:25    2012-01-24  1542763288815030273             8  ...
# 2022-08-20 02:55:52  @aaronparnas @patryanuc #ny #newyork #yankees ...
# 2022-08-20 02:56:52  the 19th amendment was ratified #onthisday in ...
# 2022-08-20 02:57:39  @cbouzy @filmystic yes we are not happy we are...
# 2022-08-20 02:57:54  🚨breaking: a michigan judge rules that prosecu...
#
#                     sentiment
# tweetcreatedts
# 2022-07-01 06:53:25   LABEL_0
# 2022-07-01 06:53:32   LABEL_0
# 2022-07-01 06:53:35   LABEL_0
# 2022-07-01 06:53:38   LABEL_2
# 2022-07-01 06:53:40   LABEL_0
# ...                       ...
# 2022-08-20 02:55:19   LABEL_0
# 2022-08-20 02:55:52   LABEL_0
# 2022-08-20 02:56:52   LABEL_2
# 2022-08-20 02:57:39   LABEL_0
# 2022-08-20 02:57:54   LABEL_0
#
# [394971 rows x 22 columns]

# %%
value_counts = df['sentiment'].value_counts()

print(value_counts) # Label 0 is negative (pro-choice), Label 1 is neutral, Label 2 is Positive (anti-abortion)?
# Out:
# sentiment
# LABEL_0    265541
# LABEL_2    129430
# Name: count, dtype: int64

# %%
# grouping by Mode
mode_sentiment = df.groupby('hashed_userid')['sentiment'].agg(lambda x: x.mode()[0])
value_counts_mode = mode_sentiment.value_counts()
print(value_counts_mode)
# Out:
# sentiment
# LABEL_0    134945
# LABEL_2     59479
# Name: count, dtype: int64

# %%
# grouping by Mean
label_mapping = {
    'LABEL_0': 0,
    'LABEL_1': 1,
    'LABEL_2': 2
}

df['sentiment_int'] = df['sentiment'].replace(label_mapping)
user_mean_sentiment = df.groupby('hashed_userid')['sentiment_int'].mean()

value_counts_mean = user_mean_sentiment.value_counts()
print(value_counts_mean)
# Out:
# sentiment_int
# 0.000000    107360
# 2.000000     54949
# 1.000000     12631
# 0.666667      4991
# 1.333333      2402
#              ...
# 0.232558         1
# 0.490196         1
# 0.259740         1
# 0.150000         1
# 0.138614         1
# Name: count, Length: 463, dtype: int64

# %%
# Summary of Mean grouping

import matplotlib.pyplot as plt

# Plotting the distribution as a histogram
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
user_mean_sentiment.hist()
plt.title('Histogram of User Mean Sentiment')
plt.xlabel('Mean Sentiment')
plt.ylabel('Frequency')

# Plotting the distribution as a boxplot
plt.subplot(1, 2, 2)
user_mean_sentiment.plot.box()
plt.title('Boxplot of User Mean Sentiment')
plt.ylabel('Mean Sentiment')

# Showing the plots
plt.tight_layout()
plt.show()

# Printing summary statistics
user_mean_sentiment.describe()
# Out:
# count    194424.000000
# mean          0.704804
# std           0.876250
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max           2.000000
# Name: sentiment_int, dtype: float64

# %%
filtered_df_2 = df[df['sentiment_int'] == 2]
filtered_df_2.to_csv("tweet_data_score2.csv")

# %%
filtered_df_1 = df[df['sentiment_int'] == 1]
filtered_df_1.to_csv("tweet_data_score1.csv")

# %%
filtered_df_0 = df[df['sentiment_int'] == 0]
filtered_df_0.to_csv("tweet_data_score0.csv")
