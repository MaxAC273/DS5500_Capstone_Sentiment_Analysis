# %%
from LDA_DistilBERT_functions import *
df = pd.read_pickle("twitter_data_LDA_DistilBERT.pkl")
# Out:
# C:\Users\Alan\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# C:\Users\Alan\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
# filter for "Roe vs. Wade Discussion" topic
topic7_df = df[df['predicted_topic'] == 7]

# %%
topic7_df
# Out:
#         Unnamed: 0         hashed_userid  masked_username           location  \
# 10              10   5347199455109023674      ******tMila                NaN
# 11              11  24675713035788260516  ********lfqueen                 🇺🇸
# 12              12  98280361691684731650  ********fficial          Hong Kong
# 20              20  37890391597722678832       *****p1988    📍Annapolis,U.S.
# 28              28  19071150623816123323   *******ORourke                NaN
# ...            ...                   ...              ...                ...
# 415356      415356  36806269927135459661       *****veGuy  San Francisco, CA
# 415360      415360  67511776435981404812     ******eNorth      Beverly Hills
# 415361      415361  58132592242300554873  ********1627809      United States
# 415364      415364  97600811567002977784     ******eUnite       Georgia, USA
# 415370      415370  95273352056344375133        *****kh59    Terre Haute, IN
#
# ...

# %%
# pip install gensim

topic_7 = LDATopicModeler(topic7_df,'processed_text')
topic_7.create_corpus_and_dictionary()
topic_7.compute_coherence_values()
topic_7.plot_optimal_number_of_topics()

# %%
topic_7.train_lda_model(num_topics=14)

# %%
# pip install pyldavis
topic_7.visualize_topics()
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2774415978477666241553207638" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
topic_7.display_topic_words()
# Out:
# Topic: 1
# Words: resistance, new, book, legal, voter, without, power, politics, daughter, ballot, check, around, parent, public, call
#
# Topic: 2
# Words: know, equal, equality, magats, fbr, cw22, november, psychology, victim, control, thread, female, class, thats, end
#
# Topic: 3
# Words: like, read, era, doctor, even, cant, thank, save, youre, story, standing, 2nd, direct, publish, feel
#
# Topic: 4
# Words: florida, court, history, stop, theyre, constitutional, supreme, judge, held, look, ever, better, hope, fetus, usa
#
# Topic: 5
# Words: state, vote, say, adulthumanfemale, time, voteblue, way, issue, reproductiverights, news, line, well, male, votebluein2022, kansa
#
# Topic: 6
# Words: abortion, people, law, dont, get, life, support, decision, potus, today, prolife, going, keep, mother, shes
#
# Topic: 7
# Words: want, one, humanrights, country, good, still, old, medical, work, carry, everyone, young, overturn, bluecrew, term
#
# Topic: 8
# ...

# %%
topic_7.add_lda_results_to_dataframe("further_topics_label")
# Out:
# C:\Users\Alan\Documents\GitHub\DS5500_Capstone_Sentiment_Analysis\LDA_DistilBERT_functions.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dataframe[column_name] = dominant_topics

# %%
topic_labels = {
    1: 'Political Mobilization and Legal Battles',
    2: 'Equality, Control, and Ideological Divides',
    3: 'Personal Stories and Social Media Engagement',
    4: 'Judicial Decisions and State Responses',
    5: 'Electoral Influence and Reproductive Rights',
    6: 'Abortion Debate: Ethics and Policies',
    7: 'Human Rights and Societal Values',
    8: 'Political Strategies and Electoral Implications',
    9: "Activism and the Supreme Court's Influence",
    10: 'Healthcare, Freedom, and Reproductive Rights',
    11: "Women's Health and Rights Advocacy",
    12: 'Bodily Autonomy and the Right to Choose',
    13: 'Social Justice and Family Planning',
    14: 'Social Change and the Role of Government'
}

topic_7.apply_topic_labels(topic_labels, "further_topics_label", "_further_topics_name")
# Out:
# C:\Users\Alan\Documents\GitHub\DS5500_Capstone_Sentiment_Analysis\LDA_DistilBERT_functions.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.dataframe[output_column] = self.dataframe[input_column].apply(lambda topic_id: topic_labels.get(topic_id, "Unknown Topic"))

# %%
topic7_df[["further_topics_label", "_further_topics_name"]]
# Out:
#         further_topics_label                             _further_topics_name
# 10                        10     Healthcare, Freedom, and Reproductive Rights
# 11                         6             Abortion Debate: Ethics and Policies
# 12                         5      Electoral Influence and Reproductive Rights
# 20                         8  Political Strategies and Electoral Implications
# 28                         0                                    Unknown Topic
# ...                      ...                                              ...
# 415356                    10     Healthcare, Freedom, and Reproductive Rights
# 415360                     8  Political Strategies and Electoral Implications
# 415361                    10     Healthcare, Freedom, and Reproductive Rights
# 415364                     8  Political Strategies and Electoral Implications
# 415370                    10     Healthcare, Freedom, and Reproductive Rights
#
# [110963 rows x 2 columns]

# %%
topic_count = topic7_df["_further_topics_name"].value_counts()
topic_count
# Out:
# _further_topics_name
# Healthcare, Freedom, and Reproductive Rights       40410
# Political Strategies and Electoral Implications    37726
# Electoral Influence and Reproductive Rights        23885
# Women's Health and Rights Advocacy                  3311
# Judicial Decisions and State Responses              1979
# Abortion Debate: Ethics and Policies                 920
# Activism and the Supreme Court's Influence           845
# Personal Stories and Social Media Engagement         586
# Human Rights and Societal Values                     564
# Political Mobilization and Legal Battles             266
# Unknown Topic                                        149
# Bodily Autonomy and the Right to Choose              138
# Social Justice and Family Planning                    95
# Equality, Control, and Ideological Divides            89
# Name: count, dtype: int64

# %%
pos_topic7_df = topic7_df[topic7_df['sentiment'] == "POSITIVE"]
neg_topic7_df = topic7_df[topic7_df['sentiment'] == "NEGATIVE"]

# %%
topic_count_pos = pos_topic7_df["_further_topics_name"].value_counts()
topic_count_neg = neg_topic7_df["_further_topics_name"].value_counts()

# %%
topic_count_pos
# Out:
# _further_topics_name
# Healthcare, Freedom, and Reproductive Rights       8688
# Political Strategies and Electoral Implications    6663
# Electoral Influence and Reproductive Rights        3593
# Judicial Decisions and State Responses              478
# Women's Health and Rights Advocacy                  450
# Activism and the Supreme Court's Influence          177
# Abortion Debate: Ethics and Policies                 89
# Personal Stories and Social Media Engagement         73
# Bodily Autonomy and the Right to Choose              70
# Social Justice and Family Planning                   67
# Political Mobilization and Legal Battles             43
# Human Rights and Societal Values                     42
# Unknown Topic                                         6
# Equality, Control, and Ideological Divides            6
# Name: count, dtype: int64

# %%
topic_count_neg
# Out:
# _further_topics_name
# Healthcare, Freedom, and Reproductive Rights       31722
# Political Strategies and Electoral Implications    31063
# Electoral Influence and Reproductive Rights        20292
# Women's Health and Rights Advocacy                  2861
# Judicial Decisions and State Responses              1501
# Abortion Debate: Ethics and Policies                 831
# Activism and the Supreme Court's Influence           668
# Human Rights and Societal Values                     522
# Personal Stories and Social Media Engagement         513
# Political Mobilization and Legal Battles             223
# Unknown Topic                                        143
# Equality, Control, and Ideological Divides            83
# Bodily Autonomy and the Right to Choose               68
# Social Justice and Family Planning                    28
# Name: count, dtype: int64
