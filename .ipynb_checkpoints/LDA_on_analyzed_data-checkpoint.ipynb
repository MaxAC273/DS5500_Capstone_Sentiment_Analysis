# %%
from LDA_DistilBERT_functions import *
df = pd.read_pickle("twitter_data_LDA_DistilBERT.pkl")

# %%
# filter for "Roe vs. Wade Discussion" topic and split negative and positive sentiments
topic7_df = df[df['predicted_topic'] == 7]
pos_topic7_df = topic7_df[topic7_df['sentiment'] == "POSITIVE"]
neg_topic7_df = topic7_df[topic7_df['sentiment'] == "NEGATIVE"]

# %%
topic7_df
# Out:
#         Unnamed: 0         hashed_userid  masked_username           location  \
# 10              10   5347199455109023674      ******tMila                NaN
# 11              11  24675713035788260516  ********lfqueen                 🇺🇸
# 12              12  98280361691684731650  ********fficial          Hong Kong
# 20              20  37890391597722678832       *****p1988    📍Annapolis,U.S.
# 28              28  19071150623816123323   *******ORourke                NaN
# ...            ...                   ...              ...                ...
# 415356      415356  36806269927135459661       *****veGuy  San Francisco, CA
# 415360      415360  67511776435981404812     ******eNorth      Beverly Hills
# 415361      415361  58132592242300554873  ********1627809      United States
# 415364      415364  97600811567002977784     ******eUnite       Georgia, USA
# 415370      415370  95273352056344375133        *****kh59    Terre Haute, IN
#
#         following  followers  totaltweets usercreateddt              tweetid  \
# 10           1181        676        10467    2021-02-20  1542763626481606656
# 11          10513       9829       138127    2017-05-26  1542763634849239040
# 12            606      40874         2450    2021-08-18  1542763696333565953
# 20           5001        398         3492    2020-04-22  1542763772951072768
# 28            558        230          381    2019-01-14  1542764107526508545
# ...           ...        ...          ...           ...                  ...
# 415356        382        325          805    2022-07-08  1560821261843845121
# 415360       4356       3684        12052    2014-02-13  1560821587221237760
# 415361         63         23          242    2022-04-15  1560822044287180802
# 415364       4913       3265        84241    2017-02-04  1560822328338141184
# 415370        854        298        16999    2017-10-10  1560823347583361024
#
#             tweetcreatedts  ...     quoted_status_id  \
# 10     2022-07-01 06:54:46  ...  1540834913049628672
# 11     2022-07-01 06:54:48  ...                    0
# 12     2022-07-01 06:55:03  ...                    0
# 20     2022-07-01 06:55:21  ...                    0
# 28     2022-07-01 06:56:41  ...  1542755656603762688
# ...                    ...  ...                  ...
# 415356 2022-08-20 02:49:22  ...                    0
# 415360 2022-08-20 02:50:39  ...                    0
# 415361 2022-08-20 02:52:28  ...                    0
# 415364 2022-08-20 02:53:36  ...                    0
# 415370 2022-08-20 02:57:39  ...                    0
#
#                        extractedts  \
# 10      2022-07-01 12:03:30.967903
# 11      2022-07-01 12:03:30.953310
# 12      2022-07-01 12:03:30.916359
# 20      2022-07-01 12:03:30.688946
# 28      2022-07-01 12:03:30.456545
# ...                            ...
# 415356  2022-08-20 02:58:51.204647
# 415360  2022-08-20 02:58:51.161705
# 415361  2022-08-20 02:58:51.152486
# 415364  2022-08-20 02:58:51.124606
# 415370  2022-08-20 02:58:51.066790
#
#                                              cleaned_text  \
# 10      yes fuck you were voting blue ussupremecourt g...
# 11      lindseygrahamsc that is a beautiful gif i borr...
# 12      us president joebiden said he would support ch...
# 20      its very disturbing that this present body of ...
# 28      i am on this episode of interrogating hardy  g...
# ...                                                   ...
# 415356  maestramarney 77sunnyandclear beekindplz lovem...
# 415360  jojofromjerz acyn bill majer is almost 66 with...
# 415361  therobyntodd xoalexandria_xo anthonybibbs19 ti...
# 415364  nytimes suzeqknits im sure they just want to p...
# 415370  cbouzy filmystic yes we are not happy we are a...
#
#                                         preprocessed_text  \
# 10      yes fuck voting blue ussupremecourt gop leader...
# 11      lindseygrahamsc beautiful gif borrowed amp dep...
# 12      u president joebiden said would support changi...
# 20      disturbing present body scotus weighing justic...
# 28      episode interrogating hardy give listen find t...
# ...                                                   ...
# 415356  maestramarney 77sunnyandclear beekindplz lovem...
# 415360  jojofromjerz acyn bill majer almost 66 kid nev...
# 415361  therobyntodd xoalexandria_xo anthonybibbs19 ti...
# 415364  nytimes suzeqknits im sure want punish im sure...
# 415370  cbouzy filmystic yes happy angry mybodymychoic...
#
#                                            processed_text  dominant_topic  \
# 10      [yes, fuck, voting, blue, ussupremecourt, gop,...               1
# 11      [lindseygrahamsc, beautiful, gif, borrowed, de...               7
# 12      [u, president, joebiden, said, support, changi...               7
# 20      [disturbing, present, body, scotus, weighing, ...               7
# 28      [episode, interrogating, hardy, give, listen, ...               4
# ...                                                   ...             ...
# 415356  [maestramarney, 77sunnyandclear, beekindplz, l...               7
# 415360  [jojofromjerz, acyn, bill, majer, almost, 66, ...               4
# 415361  [therobyntodd, xoalexandria_xo, anthonybibbs19...               7
# 415364  [nytimes, suzeqknits, sure, want, punish, sure...               7
# 415370  [cbouzy, filmystic, yes, happy, angry, mybodym...               7
#
#                                 topic_label  predicted_topic  \
# 10                   Abortion Rights Debate                7
# 11                  Roe vs. Wade Discussion                7
# 12                  Roe vs. Wade Discussion                7
# 20                  Roe vs. Wade Discussion                7
# 28      Supreme Court and Legal Discussions                7
# ...                                     ...              ...
# 415356              Roe vs. Wade Discussion                7
# 415360  Supreme Court and Legal Discussions                7
# 415361              Roe vs. Wade Discussion                7
# 415364              Roe vs. Wade Discussion                7
# 415370              Roe vs. Wade Discussion                7
#
#           predicted_topic_label  sentiment
# 10      Roe vs. Wade Discussion   NEGATIVE
# 11      Roe vs. Wade Discussion   POSITIVE
# 12      Roe vs. Wade Discussion   POSITIVE
# 20      Roe vs. Wade Discussion   NEGATIVE
# 28      Roe vs. Wade Discussion   POSITIVE
# ...                         ...        ...
# 415356  Roe vs. Wade Discussion   NEGATIVE
# 415360  Roe vs. Wade Discussion   NEGATIVE
# 415361  Roe vs. Wade Discussion   NEGATIVE
# 415364  Roe vs. Wade Discussion   NEGATIVE
# 415370  Roe vs. Wade Discussion   NEGATIVE
#
# [110963 rows x 29 columns]

# %%
# pip install gensim

topic_7 = LDATopicModeler(topic7_df,'processed_text')
topic_7.create_corpus_and_dictionary()
topic_7.compute_coherence_values()
topic_7.plot_optimal_number_of_topics()

# %%
topic_7.train_lda_model(num_topics=8)

# %%
# pip install pyldavis
topic_7.visualize_topics()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # pip install pyldavis
# ----> 2 topic_7.visualize_topics()
#
# File ~/Documents/GitHub/DS5500_Capstone_Sentiment_Analysis/LDA_DistilBERT_functions.py:158, in LDATopicModeler.visualize_topics(self)
#     154 def visualize_topics(self):
#     155     """
#     156     Visualizes the topics using pyLDAvis.
#     157     """
# --> 158     import pyLDAvis.gensim_models as gensimvis
#     159     import pyLDAvis
#     160     pyLDAvis.enable_notebook()
#
# ModuleNotFoundError: No module named 'pyLDAvis'

# %%
# Out:
# Collecting pyldavis
#   Obtaining dependency information for pyldavis from https://files.pythonhosted.org/packages/6b/5a/66364c6799f2362bfb9b7100bc1ce6ffcdfe7f17e8d2e85a591bfe427643/pyLDAvis-3.4.1-py3-none-any.whl.metadata
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting numpy>=1.24.2 (from pyldavis)
#   Obtaining dependency information for numpy>=1.24.2 from https://files.pythonhosted.org/packages/7d/24/ce71dc08f06534269f66e73c04f5709ee024a1afe92a7b6e1d73f158e1f8/numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 759.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (1.11.4)
# Collecting pandas>=2.0.0 (from pyldavis)
#   Obtaining dependency information for pandas>=2.0.0 from https://files.pythonhosted.org/packages/a0/75/b839e48677d69dc149735692497afc00e444b4760b0a08e0285aa36db240/pandas-2.2.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata
#   Downloading pandas-2.2.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (1.2.0)
# Requirement already satisfied: jinja2 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (3.1.2)
# Requirement already satisfied: numexpr in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (2.8.4)
# Collecting funcy (from pyldavis)
#   Obtaining dependency information for funcy from https://files.pythonhosted.org/packages/d5/08/c2409cb01d5368dcfedcbaffa7d044cc8957d57a9d0855244a5eb4709d30/funcy-2.0-py2.py3-none-any.whl.metadata
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (1.2.2)
# Requirement already satisfied: gensim in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (4.3.2)
# Requirement already satisfied: setuptools in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pyldavis) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0.0->pyldavis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0.0->pyldavis) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from pandas>=2.0.0->pyldavis) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0.0->pyldavis) (2.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from gensim->pyldavis) (6.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from jinja2->pyldavis) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/alancheung/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyldavis) (1.16.0)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 2.0 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 1.1 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.0-cp39-cp39-macosx_10_9_x86_64.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 10.1/12.5 MB 138.8 kB/s eta 0:00:18
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/http/client.py", line 462, in read
#     n = self.readinto(b)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/http/client.py", line 506, in readinto
#     n = self.fp.readinto(b)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 161, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 565, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/operations/prepare.py", line 479, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/network/download.py", line 183, in __call__
#     for chunk in chunks:
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/cli/progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 587, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/alancheung/opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/urllib3/response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# Note: you may need to restart the kernel to use updated packages.
